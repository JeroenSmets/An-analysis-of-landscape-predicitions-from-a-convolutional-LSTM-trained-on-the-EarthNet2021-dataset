# %%
import numpy as np
import os
for dirname1 in os.listdir(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\context"):
    string1 = os.path.basename(dirname1)
    for dirname in os.listdir(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\context\\" + string1):
        string = os.path.basename(dirname)
        # Loading File
        sample = np.load(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\context\\" + string1 + "\\" + string)
        # Accessing mesoscale dynamic variables (the E-OBS weather data)
        md = dict(sample)
        md['mesodynamic'][:,:,1,:] = md['mesodynamic'][:,:,1,:] + (5/50)
        sample['mesodynamic'][:,:,1,:] = md['mesodynamic'][:,:,1,:]

        if not os.path.exists(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\contextplus5mm\\" + string1):
            os.mkdir(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\contextplus5mm\\" + string1)

        #if not os.path.exists(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\contextplus5mm\\" + string1 + "\\" + string):
        np.savez_compressed(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\contextplus5mm\\" + string1 + "\\" + string,**md)
        print("Saved the following file:",string)
# Out:
# Saved the following file: context_29SND_2017-06-20_2017-11-16_1977_2105_1721_1849_30_110_26_106.npz
# Saved the following file: context_29SND_2017-06-20_2017-11-16_2617_2745_1465_1593_40_120_22_102.npz
# Saved the following file: context_29SND_2017-06-20_2017-11-16_953_1081_3641_3769_14_94_56_136.npz
# Saved the following file: context_29SND_2017-06-30_2017-11-26_1081_1209_1721_1849_16_96_26_106.npz
# Saved the following file: context_29SND_2017-06-30_2017-11-26_1209_1337_1977_2105_18_98_30_110.npz
# Saved the following file: context_29SND_2017-06-30_2017-11-26_2617_2745_3897_4025_40_120_60_140.npz
# Saved the following file: context_29SND_2017-06-30_2017-11-26_3129_3257_4153_4281_48_128_64_144.npz
# Saved the following file: context_29SND_2017-06-30_2017-11-26_4281_4409_2489_2617_66_146_38_118.npz
# Saved the following file: context_29SND_2017-06-30_2017-11-26_4409_4537_5049_5177_68_148_78_158.npz
# ...

# %%
import numpy as np
sampletest = np.load(r"C:\Users\jeroe\Documents\Masterthesis\weather2land\code\data\en21ds_full\iid_test_split\context\29SND\context_29SND_2020-01-01_2020-05-29_4153_4281_3897_4025_64_144_60_140.npz")
sampletest['mesodynamic'][:,:,1,:]
# Out:
# array([[[0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         [0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         [0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         ...,
#         [0.764 , 0.7603, 0.768 , ..., 0.692 , 0.684 , 0.664 ],
#         [0.764 , 0.7603, 0.768 , ..., 0.692 , 0.684 , 0.664 ],
#         [0.764 , 0.7603, 0.768 , ..., 0.692 , 0.684 , 0.664 ]],
#
#        [[0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         [0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         [0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         ...,
#         [0.764 , 0.7603, 0.768 , ..., 0.692 , 0.684 , 0.664 ],
#         [0.764 , 0.7603, 0.768 , ..., 0.692 , 0.684 , 0.664 ],
#         [0.764 , 0.7603, 0.768 , ..., 0.692 , 0.684 , 0.664 ]],
#
#        [[0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
#         [0.768 , 0.756 , 0.768 , ..., 0.688 , 0.684 , 0.664 ],
# ...
